# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriya-ms/OIBSIP/blob/main/oibsip_task3_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CAR PRICE PREDICTION**

# %%
#IMPORT NECESSARY LIBRARIES

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.shape
# Out:
# (301, 9)

# %%
df.size
# Out:
# 2709

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df[df.duplicated()]  #to find the duplicates
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Selling_type Transmission  Owner
# 17       Dealer       Manual      0
# 93       Dealer    Automatic      0

# %%
df=df.drop_duplicates() #data frame after deleting duplicates
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Car_Name'].value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# brio                        10
# fortuner                    10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     58
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df['Selling_type'].value_counts()
# Out:
# Dealer        193
# Individual    106
# Name: Selling_type, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Manual       260
# Automatic     39
# Name: Transmission, dtype: int64

# %% [markdown]
# **ENCODING**

# %%
#label encoding to convert categorical values in input columns to numerical

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
df['Car_Name']=label.fit_transform(df['Car_Name'])
# Out:
# <ipython-input-18-0ec6ab0bbd98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Car_Name']=label.fit_transform(df['Car_Name'])

# %%
df['Fuel_Type']=label.fit_transform(df['Fuel_Type'])
# Out:
# <ipython-input-19-5e7fe4997d72>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fuel_Type']=label.fit_transform(df['Fuel_Type'])

# %%
df['Selling_type']=label.fit_transform(df['Selling_type'])
# Out:
# <ipython-input-20-f0d477ee97a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selling_type']=label.fit_transform(df['Selling_type'])

# %%
df['Transmission']=label.fit_transform(df['Transmission'])
# Out:
# <ipython-input-21-c42bd9ed97e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transmission']=label.fit_transform(df['Transmission'])

# %%
df
# Out:
#      Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0          90  2014           3.35           5.59       27000          2
# 1          93  2013           4.75           9.54       43000          1
# 2          68  2017           7.25           9.85        6900          2
# 3          96  2011           2.85           4.15        5200          2
# 4          92  2014           4.60           6.87       42450          1
# ..        ...   ...            ...            ...         ...        ...
# 296        69  2016           9.50          11.60       33988          1
# 297        66  2015           4.00           5.90       60000          2
# 298        69  2009           3.35          11.00       87934          2
# 299        69  2017          11.50          12.50        9000          1
# 300        66  2016           5.30           5.90        5464          2
#
#      Selling_type  Transmission  Owner
# 0               0             1      0
# ...

# %%
x=df.drop(['Selling_Price'],axis=1)
x
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 0          90  2014           5.59       27000          2             0
# 1          93  2013           9.54       43000          1             0
# 2          68  2017           9.85        6900          2             0
# 3          96  2011           4.15        5200          2             0
# 4          92  2014           6.87       42450          1             0
# ..        ...   ...            ...         ...        ...           ...
# 296        69  2016          11.60       33988          1             0
# 297        66  2015           5.90       60000          2             0
# 298        69  2009          11.00       87934          2             0
# 299        69  2017          12.50        9000          1             0
# 300        66  2016           5.90        5464          2             0
#
#      Transmission  Owner
# 0               1      0
# 1               1      0
# ...

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
#Seperating into Training data and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 226        82  2015           5.70       24678          2             0
# 69         71  2016          20.91       12000          2             0
# 224        94  2013           9.40       36198          2             0
# 38         63  2016           3.76       10079          2             0
# 16         76  2015          10.79       41678          1             0
# ..        ...   ...            ...         ...        ...           ...
# 190        14  2008           0.75       60000          2             1
# 72         71  2013          18.61       56001          2             0
# 108        48  2016           1.50       18000          2             1
# 272        69  2015          10.00       27600          2             0
# 104        46  2017           1.47        4100          2             1
#
#      Transmission  Owner
# 226             1      0
# 69              1      0
# ...

# %%
x_test
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 283        69  2016          11.80        9010          2             0
# 267        69  2016           9.40       19434          1             0
# 166        25  2016           0.55        1000          2             1
# 9          68  2015           8.92       42367          1             0
# 78         71  2010          22.83       80000          2             0
# ..        ...   ...            ...         ...        ...           ...
# 134        51  2017           0.81       11800          2             1
# 73         80  2011           5.71       43000          2             0
# 15         76  2016          10.79       43000          1             0
# 10         62  2017           3.60        2135          2             0
# 159        31  2017           0.51        4000          2             1
#
#      Transmission  Owner
# 283             1      0
# 267             1      0
# ...

# %%
y_train
# Out:
# 226     5.25
# 69     14.25
# 224     5.11
# 38      3.00
# 16      7.25
#        ...
# 190     0.20
# 72      7.45
# 108     1.20
# 272     7.50
# 104     1.35
# Name: Selling_Price, Length: 209, dtype: float64

# %%
y_test
# Out:
# 283    8.99
# 267    8.35
# 166    0.45
# 9      7.45
# 78     5.25
#        ...
# 134    0.65
# 73     2.65
# 15     7.75
# 10     2.85
# 159    0.45
# Name: Selling_Price, Length: 90, dtype: float64

# %% [markdown]
# **NORMALISATION**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=scaler.transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %% [markdown]
# **REGRESSION PLOT**

# %%
import seaborn as sns

# %%
sns.regplot(x=df['Car_Name'],y=y,color='green')
# Out:
# <Axes: xlabel='Car_Name', ylabel='Selling_Price'>

# %%
sns.regplot(x=df['Year'],y=y,color='yellow')
# Out:
# <Axes: xlabel='Year', ylabel='Selling_Price'>

# %% [markdown]
# **MODEL CREATION**

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 7.46472652,  7.35416662,  1.25687554,  6.58460671, 11.49812624,
#         4.45681814,  8.52917997,  1.80011183,  8.60753275, -1.04917964,
#         9.97092816, -1.01563953,  1.12511597,  1.70738507,  5.22149389,
#         5.10468048,  1.1352747 ,  1.89633326, 21.57342197,  1.06042601,
#         1.14013752,  2.66768991,  5.67662647,  0.39821796,  5.87556941,
#         7.79626854,  8.29343849,  1.27043572,  5.00630725,  5.13159295,
#         6.24078196,  5.90401091,  5.88261257,  2.855591  ,  3.0791058 ,
#         6.72499313,  1.3471881 , -4.33722008,  1.48469076, 10.70836818,
#         7.14735028,  8.77010448,  1.45800655,  4.33169273,  1.1594846 ,
#        -2.2208542 ,  8.15702793,  4.27505328,  6.03113947, -0.68354276,
#         0.5053941 ,  0.04829097, 11.46881952,  9.07432965,  7.28733832,
#         5.95542139,  3.78545084,  3.61113087,  9.20180459,  9.16139257,
#         5.40921742,  0.60385162,  0.02320464, -1.11397778,  2.4858576 ,
# ...

# %% [markdown]
# **PRINT SLOPE AND CO-EFFICIENT**

# %%
print("slope=",model.coef_)
# Out:
# slope= [ 0.22104195  0.98846951  3.9570019  -0.26063705 -0.42412951 -0.46265025
#  -0.61893235  0.15053428]

# %%
list(zip(x,model.coef_))
# Out:
# [('Car_Name', 0.2210419480076376),
#  ('Year', 0.9884695067568396),
#  ('Present_Price', 3.9570019012315623),
#  ('Driven_kms', -0.26063704811931176),
#  ('Fuel_Type', -0.42412950569938107),
#  ('Selling_type', -0.4626502476818478),
#  ('Transmission', -0.6189323537319856),
#  ('Owner', 0.15053427798251737)]

# %%
print("constant=",model.intercept_)
# Out:
# constant= 4.60827751196172

# %% [markdown]
# **PERFORMANCE EVALUATION**

# %%
from sklearn.metrics import mean_absolute_error

# %%
print("mae=",mean_absolute_error(y_test,y_pred))
# Out:
# mae= 1.458661238555631

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("mape=",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mape= 1.3919294014329393

# %%
from sklearn.metrics import mean_squared_error
print("mse=",mean_squared_error(y_test,y_pred))
# Out:
# mse= 5.605534605184841

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 2.367601023226853

# %%
from sklearn.metrics import r2_score
print("r2_score=",r2_score(y_test,y_pred))
# Out:
# r2_score= 0.7589059878095455
