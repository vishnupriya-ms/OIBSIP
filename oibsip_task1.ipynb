# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupriya-ms/OIBSIP/blob/main/oibsip_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IRIS FLOWER CLASSIFICATION**

# %%
#IMPORT NECESSARY LIBRARIES

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# UNDERSTANDING DATA SET

# %%
df=pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.size     #total number of rows and columns
# Out:
# 900

# %%
df.shape     # number of rows,number of columns
# Out:
# (150, 6)

# %%
df.head()    # first five rows and columns
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()           #last 5 rows and columns
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.isna().sum()      #no missing values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#seperating data set into input variable and output variable

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#Dividing into xtrain,xtest,ytrain,ytest

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 81    82            5.5           2.4            3.7           1.0
# 133  134            6.3           2.8            5.1           1.5
# 137  138            6.4           3.1            5.5           1.8
# 75    76            6.6           3.0            4.4           1.4
# 109  110            7.2           3.6            6.1           2.5
# ..   ...            ...           ...            ...           ...
# 71    72            6.1           2.8            4.0           1.3
# 106  107            4.9           2.5            4.5           1.7
# 14    15            5.8           4.0            1.2           0.2
# 92    93            5.8           2.6            4.0           1.2
# 102  103            7.1           3.0            5.9           2.1
#
# [105 rows x 5 columns]

# %%
x_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 73    74            6.1           2.8            4.7           1.2
# 18    19            5.7           3.8            1.7           0.3
# 118  119            7.7           2.6            6.9           2.3
# 78    79            6.0           2.9            4.5           1.5
# 76    77            6.8           2.8            4.8           1.4
# 31    32            5.4           3.4            1.5           0.4
# 64    65            5.6           2.9            3.6           1.3
# 141  142            6.9           3.1            5.1           2.3
# 68    69            6.2           2.2            4.5           1.5
# 82    83            5.8           2.7            3.9           1.2
# 110  111            6.5           3.2            5.1           2.0
# 12    13            4.8           3.0            1.4           0.1
# 36    37            5.5           3.5            1.3           0.2
# ...

# %%
y_train
# Out:
# 81     Iris-versicolor
# 133     Iris-virginica
# 137     Iris-virginica
# 75     Iris-versicolor
# 109     Iris-virginica
#             ...
# 71     Iris-versicolor
# 106     Iris-virginica
# 14         Iris-setosa
# 92     Iris-versicolor
# 102     Iris-virginica
# Name: Species, Length: 105, dtype: object

# %%
y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 118     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 141     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 110     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 104     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 132     Iris-virginica
# 29         Iris-setosa
# 127     Iris-virginica
# 26         Iris-setosa
# 128     Iris-virginica
# 131     Iris-virginica
# 145     Iris-virginica
# 108     Iris-virginica
# 143     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
# 146     Iris-virginica
# 51     Iris-versicolor
# 27         Iris-setosa
# 4          Iris-setosa
# 32         Iris-setosa
# ...

# %% [markdown]
# **NORMALIZATION**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=scaler.transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %% [markdown]
# **MODEL CREATION**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'], dtype='<U15')

# %% [markdown]
# **PERFORMANCE EVALUATION**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay

# %%
label=['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
matrix=confusion_matrix(y_test,y_pred)
cmd=ConfusionMatrixDisplay(matrix,display_labels=label)
cmd.plot()

# %%
score=accuracy_score(y_pred,y_test)
score
# Out:
# 1.0
